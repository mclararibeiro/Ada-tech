# %%
import pandas as pd

dados = pd.read_csv('churn.csv')
display(dados)
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
#Porcentagem de 'Churn' na tabela
print(dados['Exited'].value_counts())
print(dados['Exited'].value_counts(normalize=True))
# Out:
# 0    7963
# 1    2037
# Name: Exited, dtype: int64
# 0    0.7963
# 1    0.2037
# Name: Exited, dtype: float64

# %%
#Trocando o índice para a primeira coluna
tabela = dados.set_index('RowNumber')
tabela
# Out:
#            CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602   Hargrave          619    France  Female   42       2
# 2            15647311       Hill          608     Spain  Female   41       1
# 3            15619304       Onio          502    France  Female   42       8
# 4            15701354       Boni          699    France  Female   39       1
# 5            15737888   Mitchell          850     Spain  Female   43       2
# ...               ...        ...          ...       ...     ...  ...     ...
# 9996         15606229   Obijiaku          771    France    Male   39       5
# 9997         15569892  Johnstone          516    France    Male   35      10
# 9998         15584532        Liu          709    France  Female   36       7
# 9999         15682355  Sabbatini          772   Germany    Male   42       3
# 10000        15628319     Walker          792    France  Female   28       4
#
# ...

# %%
tabela['NumOfProducts'].nunique()
# Out:
# 4

# %%
tabela_churn = tabela.query('Exited ==  1')
tabela_churn
# Out:
#            CustomerId      Surname  CreditScore Geography  Gender  Age  \
# RowNumber
# 1            15634602     Hargrave          619    France  Female   42
# 3            15619304         Onio          502    France  Female   42
# 6            15574012          Chu          645     Spain    Male   44
# 8            15656148       Obinna          376   Germany  Female   29
# 17           15737452        Romeo          653   Germany    Male   58
# ...               ...          ...          ...       ...     ...  ...
# 9982         15672754     Burbidge          498   Germany    Male   42
# 9983         15768163      Griffin          655   Germany  Female   46
# 9992         15769959  Ajuluchukwu          597    France  Female   53
# 9998         15584532          Liu          709    France  Female   36
# 9999         15682355    Sabbatini          772   Germany    Male   42
#
#            Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# RowNumber
# ...

# %%
tabela_churn.describe().round(0)
# Out:
#        CustomerId  CreditScore     Age  Tenure   Balance  NumOfProducts  \
# count      2037.0       2037.0  2037.0  2037.0    2037.0         2037.0
# mean   15690052.0        645.0    45.0     5.0   91109.0            1.0
# std       72693.0        100.0    10.0     3.0   58361.0            1.0
# min    15565706.0        350.0    18.0     0.0       0.0            1.0
# 25%    15627360.0        578.0    38.0     2.0   38340.0            1.0
# 50%    15688963.0        646.0    45.0     5.0  109349.0            1.0
# 75%    15753092.0        716.0    51.0     8.0  131433.0            2.0
# max    15815656.0        850.0    84.0    10.0  250898.0            4.0
#
#        HasCrCard  IsActiveMember  EstimatedSalary  Exited
# count     2037.0          2037.0           2037.0  2037.0
# mean         1.0             0.0         101466.0     1.0
# std          0.0             0.0          57912.0     0.0
# min          0.0             0.0             12.0     1.0
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize =(8,5))
plt.title("Análise por País")
plt.bar(tabela_churn['Geography'].value_counts().index,tabela_churn['Geography'].value_counts());
plt.xticks(rotation = 45, ha ='right');

# %%
import matplotlib.pyplot as plt

plt.figure(figsize =(8,5))
plt.title("Análise por Genero")
plt.bar(tabela_churn['Gender'].value_counts().index,tabela_churn['Gender'].value_counts());
plt.xticks(rotation = 45, ha ='right');

# %%
dados_idade = tabela_churn['Age'].value_counts()
dados_idade.head(10)
# Out:
# 46    91
# 40    89
# 43    88
# 45    87
# 48    80
# 42    77
# 47    77
# 49    75
# 44    73
# 39    72
# Name: Age, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize =(8,5))
plt.title("Análise por idade")
plt.stem(dados_idade.index,dados_idade);
plt.xlabel('Idade')
plt.ylabel('Quantidade de perda de clientes')
plt.xticks(rotation = 45, ha ='right');

# %%
dados_produtos = tabela_churn['NumOfProducts'].value_counts()
dados_produtos
# Out:
# 1    1409
# 2     348
# 3     220
# 4      60
# Name: NumOfProducts, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize =(8,5))
plt.title("Análise por Assinaturas de Produtos")
plt.bar(dados_produtos.index,dados_produtos, color = '#a1d99b');
plt.xlabel('Produtos assinados')
plt.ylabel('Número de assinantes')
plt.xticks(rotation = 45, ha ='right');

# %%
confiabilidade = tabela_churn['Tenure'].value_counts()
confiabilidade
# Out:
# 1     232
# 3     213
# 9     213
# 5     209
# 4     203
# 2     201
# 8     197
# 6     196
# 7     177
# 10    101
# 0      95
# Name: Tenure, dtype: int64

# %%
plt.figure( figsize=(15,6))
plt.bar(confiabilidade.index, confiabilidade)
plt.title('Análise da estabilidade vs churn')
plt.ylabel("Quantidade de clientes desligados")
plt.xticks( rotation=45, ha='right');

# %%
#Agrupando clientes desligados com estabilidade acima de 7
estabilidade_alta = tabela_churn.loc[tabela_churn['Tenure'] >= 7]
estabilidade_alta
# Out:
#            CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 3            15619304      Onio          502    France  Female   42       8
# 6            15574012       Chu          645     Spain    Male   44       8
# 42           15738148    Clarke          465    France  Female   51       8
# 47           15602280    Martin          829   Germany  Female   27       9
# 48           15771573   Okagbue          637   Germany  Female   39       9
# ...               ...       ...          ...       ...     ...  ...     ...
# 9957         15707861     Nucci          520    France  Female   46      10
# 9961         15681026  Lucciano          795   Germany  Female   33       9
# 9963         15594612     Flynn          702     Spain    Male   44       9
# 9983         15768163   Griffin          655   Germany  Female   46       7
# 9998         15584532       Liu          709    France  Female   36       7
#
# ...

# %%
#Quantidade de membros com estabilidade alta e desligados que eram membros ativos
membros_ativos = estabilidade_alta['IsActiveMember'].value_counts()
membros_ativos
# Out:
# 0    451
# 1    237
# Name: IsActiveMember, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize =(15,6))
plt.title("Membros ativos - Clientes desligados com estabilidade alta")
plt.pie(membros_ativos, labels = membros_ativos.index, startangle=90, autopct='%1.1f%%')
plt.show()

# %%
#Membros ativos churn
membros_ativos_totais = tabela_churn['IsActiveMember'].value_counts(normalize=True)
membros_ativos_totais
# Out:
# 0    0.639175
# 1    0.360825
# Name: IsActiveMember, dtype: float64

# %%
#Agrupando clientes por creditscore
creditscore = tabela_churn.loc[tabela_churn['CreditScore'] > 700]
creditscore
# Out:
#            CustomerId     Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 44           15755196      Lavine          834    France  Female   49       2
# 47           15602280      Martin          829   Germany  Female   27       9
# 71           15703793  Konovalova          738   Germany    Male   58       2
# 82           15663706     Leonard          777    France  Female   32       2
# 87           15762418        Gant          750     Spain    Male   22       3
# ...               ...         ...          ...       ...     ...  ...     ...
# 9885         15686974   Sergeyeva          751    France  Female   48       4
# 9961         15681026    Lucciano          795   Germany  Female   33       9
# 9963         15594612       Flynn          702     Spain    Male   44       9
# 9998         15584532         Liu          709    France  Female   36       7
# 9999         15682355   Sabbatini          772   Germany    Male   42       3
#
# ...

# %%
correlacao = tabela.corr().round(2)
correlacao
# Out:
# C:\Users\Maria Clara\AppData\Local\Temp\ipykernel_13448\1432506468.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlacao = tabela.corr().round(2)
#                  CustomerId  CreditScore   Age  Tenure  Balance  \
# CustomerId             1.00         0.01  0.01   -0.01    -0.01
# CreditScore            0.01         1.00 -0.00    0.00     0.01
# Age                    0.01        -0.00  1.00   -0.01     0.03
# Tenure                -0.01         0.00 -0.01    1.00    -0.01
# Balance               -0.01         0.01  0.03   -0.01     1.00
# NumOfProducts          0.02         0.01 -0.03    0.01    -0.30
# HasCrCard             -0.01        -0.01 -0.01    0.02    -0.01
# IsActiveMember         0.00         0.03  0.09   -0.03    -0.01
# EstimatedSalary        0.02        -0.00 -0.01    0.01     0.01
# ...

# %%
#Codigo teste
